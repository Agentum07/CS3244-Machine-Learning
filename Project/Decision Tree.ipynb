# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pydotplus as pp
import seaborn as sns

from IPython.display import display
from IPython.display import Image

from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

from sklearn.model_selection import train_test_split

from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz

# %%
class CONFIG:
    INDEXS = ["R2 Pred", "R2", "EV", "ME", "MEAN_AE", "MSE", "MEDIAN_AE"]

# %% [markdown]
# # Load Dataset

# %%
header = pd.read_csv("Dataset/header.csv", header=None)
header
# Out:
#                       0                  1                   2   \
# 0  Page Popularity/likes  Page Checkinsâ€™s  Page talking about
#
#               3         4         5         6         7         8          9   \
# 0  Page Category  Derived5  Derived6  Derived7  Derived8  Derived9  Derived10
#
#    ...                             44                               45  \
# 0  ...  Post published weekday-Friday  Post published weekday-Saturday
#
#                              46                            47  \
# 0  Base DateTime weekday-Sunday  Base DateTime weekday-Monday
#
#                               48                               49  \
# 0  Base DateTime weekday-Tuesday  Base DateTime weekday-Wednesday
#
#                                50                            51  \
# 0  Base DateTime weekday-Thursday  Base DateTime weekday-Friday
#
#                                52               53
# 0  Base DateTime weekday-Saturday  Target Variable
#
# [1 rows x 54 columns]

# %%
training_dataset = pd.read_csv("Dataset/Training/Features_Variant_1.csv",
                               header=None,
                               names=[header.iat[0, i] for i in range(0, 54)])
training_dataset.sample(n=10)
# Out:
#        Page Popularity/likes  Page Checkinsâ€™s  Page talking about  \
# 39150                2046147                  0              123685
# 39588                  90442                  0                6802
# 3046                 5970921              53096              234501
# 10019                   4233                  0                1005
# 15201                  21292              40768                 525
# 9044                 1203855                 88              101567
# 21414                 228007                  0                  24
# 23542                  12293               3744                3015
# 13924                  63888                  0                1564
# 20793                  57411              36082                1485
#
#        Page Category  Derived5  Derived6    Derived7  Derived8    Derived9  \
# 39150              9       0.0    1369.0  117.420601      69.0  157.616838
# ...

# %%
training_dataset.corr()
# Out:
#                                   Page Popularity/likes  Page Checkinsâ€™s  \
# Page Popularity/likes                          1.000000           0.044839
# Page Checkinsâ€™s                              0.044839           1.000000
# Page talking about                             0.623436           0.166850
# Page Category                                 -0.042167          -0.060181
# Derived5                                       0.059575          -0.002830
# Derived6                                       0.158714           0.169236
# Derived7                                       0.166425           0.154968
# Derived8                                       0.145216           0.121734
# Derived9                                       0.174597           0.178410
# Derived10                                      0.015750          -0.003997
# Derived11                                      0.182898           0.201226
# ...

# %%
features = training_dataset.iloc[:, :53]
features
# Out:
#        Page Popularity/likes  Page Checkinsâ€™s  Page talking about  \
# 0                     634995                  0                 463
# 1                     634995                  0                 463
# 2                     634995                  0                 463
# 3                     634995                  0                 463
# 4                     634995                  0                 463
# ...                      ...                ...                 ...
# 40944                7170111                 70              497000
# 40945                7170111                 70              497000
# 40946                7170111                 70              497000
# 40947                7170111                 70              497000
# 40948                7170111                 70              497000
#
#        Page Category  Derived5  Derived6    Derived7  Derived8    Derived9  \
# ...

# %%
labels = training_dataset.iloc[:, -1:]
labels
# Out:
#        Target Variable
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 40944                1
# 40945                2
# 40946               72
# 40947               28
# 40948               11
#
# [40949 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.3, random_state=42)

# %%
features.corr()
# Out:
#                                   Page Popularity/likes  Page Checkinsâ€™s  \
# Page Popularity/likes                          1.000000           0.044839
# Page Checkinsâ€™s                              0.044839           1.000000
# Page talking about                             0.623436           0.166850
# Page Category                                 -0.042167          -0.060181
# Derived5                                       0.059575          -0.002830
# Derived6                                       0.158714           0.169236
# Derived7                                       0.166425           0.154968
# Derived8                                       0.145216           0.121734
# Derived9                                       0.174597           0.178410
# Derived10                                      0.015750          -0.003997
# Derived11                                      0.182898           0.201226
# ...

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Model Training

# %%
def train_model(model):
    model.fit(X_train, y_train)
    predict = model.predict(X_test)
    return predict

# %%
def plot_test_predict(y_train, y_test, predict, axes=None, k=None):
    test_predict = pd.concat([pd.DataFrame(y_test).reset_index(drop=True), pd.DataFrame(predict.transpose())], axis=1)
    headers = ["Test", "Predict"]
    test_predict.columns = headers
    if axes is not None and k is not None:
        sns.lineplot(data=test_predict.sample(n=50), ax=axes[k]).set_title("Test Predict Curve k = " + str(k))
    else:
        sns.lineplot(data=test_predict.sample(n=50)).set_title("Test Predict Curve")
    plt.show()
    sns.residplot(x=y_test.to_numpy(), y=predict, lowess=True).set_title("Residuals")
    plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
def evaluate(model, X_test, y_test, predict):

    # R-Squared Prediction
    r2_pred = model.score(X_test, y_test)
    
    # R-Squared
    r2 = r2_score(y_test, predict)
    
    # Explained Variance Score
    ev = explained_variance_score(y_test, predict)
    
    # Max Error
    me = max_error(y_test, predict)
    
    # Mean Absolute Error
    mean_ae = mean_absolute_error(y_test, predict)
    
    # Mean Squared Error
    mse = mean_squared_error(y_test, predict)
    
    # Median Absolute Error
    median_ae = median_absolute_error(y_test, predict)
    
    return r2_pred, r2, ev, me, mean_ae, mse, median_ae

# %% [markdown]
# ## Draw Tree

# %%
def draw_tree(model, X_train, y_train):
    dot_data = tree.export_graphviz(model, out_file=None,
                                    feature_names=X_train.columns,
                                    class_names=y_train.columns,  
                                    filled=True,
                                    rounded=True,
                                    special_characters=True)
    graph = pp.graph_from_dot_data(dot_data)
    img = Image(graph.create_png())
    display(img)

# %% [markdown]
# ## Final Model

# %%
def train_final_model(max_depth=None, min_samples_split=2):
    # DecisionTreeRegressor
    model = DecisionTreeRegressor(max_depth=max_depth, min_samples_split=min_samples_split)

    # Model Training
    predict = train_model(model)
    plot_test_predict(y_train, y_test, predict)

    # Model Evaluation
    r2_pred, r2, ev, me, mean_ae, mse, median_ae = evaluate(model, X_test, y_test, predict)

    results = pd.DataFrame({
        "Index": CONFIG.INDEXS, 
        "Mean": [r2_pred, r2, ev, me, mean_ae, mse, median_ae]
    })
    print(results)
    draw_tree(model, X_train, y_train)

# %%
train_final_model(max_depth=10, min_samples_split=.015)
# Out:
#        Index        Mean
# 0    R2 Pred    0.483877
# 1         R2    0.483877
# 2         EV    0.484041
# 3         ME  768.611702
# 4    MEAN_AE    4.982692
# 5        MSE  524.116312
# 6  MEDIAN_AE    0.557078
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19432/2744139638.py in <module>
# ----> 1 train_final_model(max_depth=10, min_samples_split=.015)
#
# ~\AppData\Local\Temp/ipykernel_19432/4227304133.py in train_final_model(max_depth, min_samples_split)
#      15     })
#      16     print(results)
# ---> 17     draw_tree(model, X_train, y_train)
#
# ~\AppData\Local\Temp/ipykernel_19432/2940626832.py in draw_tree(model, X_train, y_train)
#       7                                     special_characters=True)
#       8     graph = pp.graph_from_dot_data(dot_data)
# ----> 9     img = Image(graph.create_png())
#      10     display(img)
#
# ...

# %%
train_final_model(max_depth=10, min_samples_split=0.01)
# Out:
#        Index        Mean
# 0    R2 Pred    0.447724
# 1         R2    0.447724
# 2         EV    0.447932
# 3         ME  768.611702
# 4    MEAN_AE    4.907189
# 5        MSE  560.829133
# 6  MEDIAN_AE    0.532129
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19432/1066829007.py in <module>
# ----> 1 train_final_model(max_depth=10, min_samples_split=0.01)
#
# ~\AppData\Local\Temp/ipykernel_19432/4227304133.py in train_final_model(max_depth, min_samples_split)
#      15     })
#      16     print(results)
# ---> 17     draw_tree(model, X_train, y_train)
#
# ~\AppData\Local\Temp/ipykernel_19432/2940626832.py in draw_tree(model, X_train, y_train)
#       7                                     special_characters=True)
#       8     graph = pp.graph_from_dot_data(dot_data)
# ----> 9     img = Image(graph.create_png())
#      10     display(img)
#
# ...

# %%
df = training_dataset

# %%
df.insert(47, "posted on weekday1", (df["Post published weekday-Monday"] | df["Post published weekday-Tuesday"] | df["Post published weekday-Wednesday"] | df["Post published weekday-Thursday"] | df["Post published weekday-Friday"]).astype("int"))

# %%
df.head()
# Out:
#    Page Popularity/likes  Page Checkinsâ€™s  Page talking about  \
# 0                 634995                  0                 463
# 1                 634995                  0                 463
# 2                 634995                  0                 463
# 3                 634995                  0                 463
# 4                 634995                  0                 463
#
#    Page Category  Derived5  Derived6   Derived7  Derived8   Derived9  \
# 0              1       0.0     806.0  11.291045       1.0  70.495138
# 1              1       0.0     806.0  11.291045       1.0  70.495138
# 2              1       0.0     806.0  11.291045       1.0  70.495138
# 3              1       0.0     806.0  11.291045       1.0  70.495138
# 4              1       0.0     806.0  11.291045       1.0  70.495138
#
#    Derived10  ...  Post published weekday-Saturday  \
# 0        0.0  ...                                0
# 1        0.0  ...                                0
# ...

# %%
df.insert(47, "posted on weekend", (df["Post published weekday-Sunday"] | df["Post published weekday-Saturday"]).astype("int"))

# %%
df.drop(["Post published weekday-Saturday", "Post published weekday-Sunday", "Post published weekday-Monday", "Post published weekday-Tuesday", "Post published weekday-Wednesday", "Post published weekday-Thursday", "Post published weekday-Friday"], axis = 1, inplace = True)

# %%
df.corr()
# Out:
#                                  Page Popularity/likes  Page Checkinsâ€™s  \
# Page Popularity/likes                         1.000000           0.044839
# Page Checkinsâ€™s                             0.044839           1.000000
# Page talking about                            0.623436           0.166850
# Page Category                                -0.042167          -0.060181
# Derived5                                      0.059575          -0.002830
# Derived6                                      0.158714           0.169236
# Derived7                                      0.166425           0.154968
# Derived8                                      0.145216           0.121734
# Derived9                                      0.174597           0.178410
# Derived10                                     0.015750          -0.003997
# Derived11                                     0.182898           0.201226
# Derived12                                     0.162418           0.128663
# ...

# %%
# df.drop("Post Promotion Status", axis = 1, inplace = True)
features = df.iloc[:, :46]
labels = df.iloc[:, -1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.3, random_state=42)

# %%
train_final_model(max_depth=12, min_samples_split=.015)
# Out:
#        Index        Mean
# 0    R2 Pred    0.483889
# 1         R2    0.483889
# 2         EV    0.484054
# 3         ME  768.611702
# 4    MEAN_AE    4.977357
# 5        MSE  524.104503
# 6  MEDIAN_AE    0.525223
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19432/1179205372.py in <module>
# ----> 1 train_final_model(max_depth=12, min_samples_split=.015)
#
# ~\AppData\Local\Temp/ipykernel_19432/4227304133.py in train_final_model(max_depth, min_samples_split)
#      15     })
#      16     print(results)
# ---> 17     draw_tree(model, X_train, y_train)
#
# ~\AppData\Local\Temp/ipykernel_19432/2940626832.py in draw_tree(model, X_train, y_train)
#       7                                     special_characters=True)
#       8     graph = pp.graph_from_dot_data(dot_data)
# ----> 9     img = Image(graph.create_png())
#      10     display(img)
#
# ...

# %%
df["Post Promotion Status"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 40944    0
# 40945    0
# 40946    0
# 40947    0
# 40948    0
# Name: Post Promotion Status, Length: 40949, dtype: int64
